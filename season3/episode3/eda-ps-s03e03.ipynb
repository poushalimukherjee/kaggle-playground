# %% [markdown]
# <a href="https://www.kaggle.com/code/poushalimukherjee/eda-ps-s03e03?scriptVersionId=116564455" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a id="contents"></a>
# # <center><font size = 4><span style="color:#3CB5CD"> <p style="background-color:#2B6E7D;font-family:'Lucida Sans';color:#F8F9D7;font-size:150%;text-align:center;border-radius:5px 5px;padding:5px">CONTENTS</p></span></font></center>
# * [<font size = 5><span style="color:#202833"><p style="font-family:'Lucida Sans';color:#2B6E7D;font-size:80%;text-align:left;padding:1px">A. Prepare Data</p></span></font>](#import-lib)
#   - [<font size = 5><span style="color:#202833"><p style="font-family:'Lucida Sans';color:#2B6E7D;font-size:70%;text-align:left;padding:1px">1. Import Libraries</p></span></font>](#prep-data)
#   - [<font size = 5><span style="color:#202833"><p style="font-family:'Lucida Sans';color:#2B6E7D;font-size:70%;text-align:left;padding:1px">2. Read Data from File into DataFrame</p></span></font>](#read-data)
# *  [<font size = 5><span style="color:#202833"><p style="font-family:'Lucida Sans';color:#2B6E7D;font-size:80%;text-align:left;padding:1px">B. Explore Features</p></span></font>](#explore-features)
#    - [<font size = 5><span style="color:#202833"><p style="font-family:'Lucida Sans';color:#2B6E7D;font-size:70%;text-align:left;padding:1px">1. Data-Types, Missing Values, NaNs</p></span></font>](#raw-data)
#    - [<font size = 5><span style="color:#202833"><p style="font-family:'Lucida Sans';color:#2B6E7D;font-size:70%;text-align:left;padding:1px">2. Create or Transform Features</p></span></font>](#create-features)
#    - [<font size = 5><span style="color:#202833"><p style="font-family:'Lucida Sans';color:#2B6E7D;font-size:70%;text-align:left;padding:1px">3. The <i>Age</i> Feature</p></span></font>](#explore-age)

# %% [markdown]
# <a id="prep-data"></a>
# # <center><font size = 4><span style="color:#3CB5CD"> <p style="background-color:#2B6E7D;font-family:'Lucida Sans';color:#F8F9D7;font-size:150%;text-align:center;border-radius:5px 5px;padding:5px">A. Prepare Data</p></span></font></center>
# #### [<font size = 5><span style="color:#202833;font-family:'Times New Roman';font-size:80%;">⬆️</span></font>](#contents)

# %% [markdown]
# <a id="import-lib"></a>
# # <font size = 4><p style="background-color:#EAEFF0;font-family:'Lucida Sans';color:#2B6E7D;font-size:130%;text-align:left;border-radius:5px 5px;padding:5px">1. Import Libraries</p></font>
#
# > [<font size = 3><p style="background-color:#FFFFFF;font-family:'Lucida Sans';color:#2B6E7D;font-size:90%;text-align:left;border-radius:5px 5px;padding:1px">Pandas</p></font>](https://pandas.pydata.org/docs/reference/index.html)
# > [<font size = 3><p style="background-color:#FFFFFF;font-family:'Lucida Sans';color:#2B6E7D;font-size:90%;text-align:left;border-radius:5px 5px;padding:1px">Numpy</p></font>](https://numpy.org/doc/stable/reference/index.html)
# > [<font size = 3><p style="background-color:#FFFFFF;font-family:'Lucida Sans';color:#2B6E7D;font-size:90%;text-align:left;border-radius:5px 5px;padding:1px">Seaborn</p></font>](https://seaborn.pydata.org/api.html)
# # [<font size = 5><span style="color:#202833;font-family:'Times New Roman';font-size:80%;">⬆️</span></font>](#contents)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# <a id="read-data"></a>
# # <center><font size = 4><span style="color:#3CB5CD"> <p style="background-color:#EAEFF0;font-family:'Lucida Sans';color:#2B6E7D;font-size:130%;text-align:left;border-radius:5px 5px;padding:5px">2. Read Data from File into DataFrame</p></span></font></center>
# #### [<font size = 5><span style="color:#202833;font-family:'Times New Roman';font-size:80%;">⬆️</span></font>](#contents)

# %%
df = pd.read_csv('/kaggle/input/playground-series-s3e3/train.csv')

# %% [markdown]
# <a id="explore-features"></a>
# # <center><font size = 4><span style="color:#3CB5CD"> <p style="background-color:#2B6E7D;font-family:'Lucida Sans';color:#F8F9D7;font-size:150%;text-align:center;border-radius:5px 5px;padding:5px">B. Explore Features of the Dataset</p></span></font></center>
# # [<font size = 5><span style="color:#202833;font-family:'Times New Roman';font-size:80%;">⬆️</span></font>](#contents)

# %% [markdown]
# <a id="raw-data"></a>
# ## <center><font size = 4><span style="color:#3CB5CD"> <p style="background-color:#EAEFF0;font-family:'Lucida Sans';color:#2B6E7D;font-size:130%;text-align:left;border-radius:5px 5px;padding:5px">1. Data-Types, Missing Values, NaNs</p></span></font></center>
# #### [<font size = 5><span style="color:#202833;font-family:'Times New Roman';font-size:80%;">⬆️</span></font>](#contents)

# %%
print('---------------------------------------------------------------------'
      ,'\n\nSHAPE:\n',      df.shape
      ,'\n\nCOLUMNS:\n',    df.columns
      ,'\n\nDATA-TYPES:\n', df.dtypes
      ,'\n---------------------------------------------------------------------\n'
     )
print('---------------------------------------------------------------------'
      ,'\n\nUNIQUE VALUES:\n', df.nunique()
      ,'\n---------------------------------------------------------------------\n'
     )
# Out:
# ---------------------------------------------------------------------
#
# SHAPE:
#  (1677, 35)
#
# COLUMNS:
#  Index(['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition'],
#       dtype='object')
#
# DATA-TYPES:
#  id                           int64
# Age                          int64
# BusinessTravel              object
# DailyRate                    int64
# ...

# %%
df.corr(method='pearson')
# Out:
#                                 id       Age  DailyRate  DistanceFromHome  \
# id                        1.000000  0.027563   0.003572          0.007871
# Age                       0.027563  1.000000   0.039686         -0.049025
# DailyRate                 0.003572  0.039686   1.000000          0.024168
# DistanceFromHome          0.007871 -0.049025   0.024168          1.000000
# Education                -0.015997  0.223545  -0.007035         -0.011436
# EmployeeCount                  NaN       NaN        NaN               NaN
# EnvironmentSatisfaction   0.044271  0.029557   0.006483          0.004959
# HourlyRate               -0.018994  0.030628  -0.001213          0.006191
# JobInvolvement           -0.016039  0.002101  -0.026725          0.010035
# JobLevel                  0.021245  0.479015   0.041369         -0.051008
# JobSatisfaction          -0.002511 -0.009273  -0.037459          0.026309
# MonthlyIncome            -0.005224  0.470758   0.027375         -0.061019
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1677 entries, 0 to 1676
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1677 non-null   int64
#  1   Age                       1677 non-null   int64
#  2   BusinessTravel            1677 non-null   object
#  3   DailyRate                 1677 non-null   int64
#  4   Department                1677 non-null   object
#  5   DistanceFromHome          1677 non-null   int64
#  6   Education                 1677 non-null   int64
#  7   EducationField            1677 non-null   object
#  8   EmployeeCount             1677 non-null   int64
#  9   EnvironmentSatisfaction   1677 non-null   int64
#  10  Gender                    1677 non-null   object
#  11  HourlyRate                1677 non-null   int64
#  12  JobInvolvement            1677 non-null   int64
#  13  JobLevel                  1677 non-null   int64
# ...

# %%
df.describe(include='all')
# Out:
#                  id          Age BusinessTravel    DailyRate  \
# count   1677.000000  1677.000000           1677  1677.000000
# unique          NaN          NaN              3          NaN
# top             NaN          NaN  Travel_Rarely          NaN
# freq            NaN          NaN           1290          NaN
# mean     838.000000    36.036971            NaN   892.749553
# std      484.252517     8.507112            NaN   374.496259
# min        0.000000    18.000000            NaN   107.000000
# 25%      419.000000    30.000000            NaN   589.000000
# 50%      838.000000    35.000000            NaN   890.000000
# 75%     1257.000000    41.000000            NaN  1223.000000
# max     1676.000000    60.000000            NaN  3921.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1677       1677.000000  1677.000000           1677
# ...

# %% [markdown]
# <a id="create-features"></a>
# ## <center><font size = 4><span style="color:#3CB5CD"> <p style="background-color:#EAEFF0;font-family:'Lucida Sans';color:#2B6E7D;font-size:130%;text-align:left;border-radius:5px 5px;padding:5px">2. Create Features or Transform Features as Needed</p></span></font></center>
# #### [<font size = 5><span style="color:#202833;font-family:'Times New Roman';font-size:80%;">⬆️</span></font>](#contents)

# %%
df['Attrition_label'] = df['Attrition'].transform(lambda x: "Left_Company" if x==1 else "Stayed")

# %% [markdown]
# <a id="explore-age"></a>
# ## <center><font size = 4><span style="color:#3CB5CD"> <p style="background-color:#EAEFF0;font-family:'Lucida Sans';color:#2B6E7D;font-size:130%;text-align:left;border-radius:5px 5px;padding:5px">3. Exploring the _'Age'_ feature with respect to other categorical features</p></span></font></center>
# #### [<font size = 5><span style="color:#202833;font-family:'Times New Roman';font-size:80%;">⬆️</span></font>](#contents)

# %%
print(  "Count of instantes of Attrition: ", df[  df['Attrition_label']   =="Left_Company"   ].shape[0]
     ,"\n------------------>       Males: ", df[  (df['Attrition_label']  =="Left_Company") 
                                             & (df['Gender']        =="Male")    ].shape[0]
     ,"\n------------------>     Females: ", df[  (df['Attrition_label']  =="Left_Company") 
                                             & (df['Gender']        =="Female")  ].shape[0]
     ,"\n"
#      ,"\nCount of instances of no-stroke: ", df[  df['stroke_label']   =="No_Stroke" ].shape[0]
#      ,"\n----------------->        Males: ", df[  (df['stroke_label']  =="No_Stroke") 
#                                                 & (df['gender']        =="Male")     ].shape[0]
#      ,"\n----------------->      Females: ", df[  (df['stroke_label']  =="No_Stroke") 
#                                                 & (df['gender']        =="Female")   ].shape[0]
#      ,"\n----------------->       Others: ", df[  (df['stroke_label']  =="No_Stroke") 
#                                                 & (df['gender']        =="Other")    ].shape[0]
     )
# Out:
# Count of instantes of Attrition:  200
# ------------------>       Males:  138
# ------------------>     Females:  62

# %%
pal = dict(Left_Company="red", Stayed="seagreen")

# %%
g1 = sns.FacetGrid(df, hue='Attrition_label', palette=pal, height=4)
g1.map(sns.histplot, "Age")
g1.add_legend()

# %%
g2 = sns.FacetGrid(df, col='Gender', hue='Attrition_label', palette=pal, height=4)
g2.map(sns.histplot, "Age")
g2.add_legend()

# %%
g3 = sns.FacetGrid(df, col='BusinessTravel', hue='Attrition_label', palette=pal, height=4)
g3.map(sns.histplot, "Age")
g3.add_legend()

# %%
g4 = sns.FacetGrid(df, col='Department', hue='Attrition_label', palette=pal, height=4)
g4.map(sns.histplot, "Age")
g4.add_legend()

# %%
g5 = sns.FacetGrid(df, col='EducationField', hue='Attrition_label', palette=pal, height=4)
g5.map(sns.histplot, "Age")
g5.add_legend()

# %%
g6 = sns.FacetGrid(df, col='EnvironmentSatisfaction', hue='Attrition_label', palette=pal, height=4)
g6.map(sns.histplot, "Age")
g6.add_legend()

# %%
g7 = sns.FacetGrid(df, col='JobLevel', hue='Attrition_label', palette=pal, height=4)
g7.map(sns.histplot, "Age")
g7.add_legend()

# %%
g8 = sns.FacetGrid(df, col='JobInvolvement', hue='Attrition_label', palette=pal, height=4)
g8.map(sns.histplot, "Age")
g8.add_legend()

# %%
g9 = sns.FacetGrid(df, col='JobSatisfaction', hue='Attrition_label', palette=pal, height=4)
g9.map(sns.histplot, "Age")
g9.add_legend()

# %%
g10 = sns.FacetGrid(df, col='MaritalStatus', hue='Attrition_label', palette=pal, height=4)
g10.map(sns.histplot, "Age")
g10.add_legend()

# %%
g11 = sns.FacetGrid(df, col='OverTime', hue='Attrition_label', palette=pal, height=4)
g11.map(sns.histplot, "Age")
g11.add_legend()

# %%
g12 = sns.FacetGrid(df, col='PerformanceRating', hue='Attrition_label', palette=pal, height=4)
g12.map(sns.histplot, "Age")
g12.add_legend()

# %%
g13 = sns.FacetGrid(df, col='RelationshipSatisfaction', hue='Attrition_label', palette=pal, height=4)
g13.map(sns.histplot, "Age")
g13.add_legend()

# %%
g14 = sns.FacetGrid(df, col='StockOptionLevel', hue='Attrition_label', palette=pal, height=4)
g14.map(sns.histplot, "Age")
g14.add_legend()

# %%
g15 = sns.FacetGrid(df, col='WorkLifeBalance', hue='Attrition_label', palette=pal, height=4)
g15.map(sns.histplot, "Age")
g15.add_legend()
